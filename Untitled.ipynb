# %%
from data_clean import *

# %%
df = get_df()
# Out:
# ['Jan 17, 2020', 'Action Comedy Crime Thriller']
# ['Jan 17, 2020', 'Action Comedy Crime Thriller', 'Feb 14, 2020', 'Action Adventure Comedy Family Sci-Fi']
# ['Jan 17, 2020', 'Action Comedy Crime Thriller', 'Feb 14, 2020', 'Action Adventure Comedy Family Sci-Fi', 'Feb 7, 2020', 'Action Adventure Comedy Crime']
# ['Jan 17, 2020', 'Action Comedy Crime Thriller', 'Feb 14, 2020', 'Action Adventure Comedy Family Sci-Fi', 'Feb 7, 2020', 'Action Adventure Comedy Crime', 'Jan 17, 2020', 'Adventure Comedy Family Fantasy']
#                             title           gross         genre  \
# 0               Bad Boys for Life  [$206,305,244]  Jan 17, 2020
# 1              Sonic the Hedgehog  [$148,974,665]  Feb 14, 2020
# 2                   Birds of Prey   [$84,158,461]   Feb 7, 2020
# 3                        Dolittle   [$77,047,065]  Jan 17, 2020
# 4               The Invisible Man   [$70,410,000]          None
# ..                            ...             ...           ...
# ...

# %%
df
# Out:
#                             title           gross         genre  \
# 0               Bad Boys for Life  [$206,305,244]  Jan 17, 2020
# 1              Sonic the Hedgehog  [$148,974,665]  Feb 14, 2020
# 2                   Birds of Prey   [$84,158,461]   Feb 7, 2020
# 3                        Dolittle   [$77,047,065]  Jan 17, 2020
# 4               The Invisible Man   [$70,410,000]          None
# ..                            ...             ...           ...
# 324                       Greater          [$527]          None
# 325                  Granny Nanny          [$432]          None
# 326                           Sol          [$327]          None
# 327        It's for Your Own Good          [$256]          None
# 328  Benjamin the Elephant (2020)           [$49]          None
#
#                               release date
# 0             Action Comedy Crime Thriller
# 1    Action Adventure Comedy Family Sci-Fi
# 2            Action Adventure Comedy Crime
# ...

# %%
import pandas as pd
